# %% [markdown]
# # Script that creates visualisation of top 1000 Citibike routes in 2022, saves config and visualisation for dashboard

# %%
import pandas as pd
import numpy as np
from keplergl import KeplerGl
from pyproj import CRS
from matplotlib import pyplot as plt
import os
# Out:
# c:\Users\seank\OneDrive\Dokumente\Career Foundry Data Analytics Course\Python_visualisation\CitiBike_NY\venv\Lib\site-packages\keplergl\keplergl.py:13: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_string

# %%
df = pd.read_parquet(r'C:\Data\Citibike_NY_2022\merged\df_weather_duration.parquet')

# %%
df.head()
# Out:
#             ride_id  rideable_type              started_at  \
# 0  FB33E3D8F21E2941  electric_bike 2022-01-01 01:49:37.374
# 1  755337295F178067  electric_bike 2022-01-01 03:21:09.754
# 2  C62CA87E3A475ADD   classic_bike 2022-01-01 08:38:18.156
# 3  CD7A2098AFCD5514   classic_bike 2022-01-01 10:33:58.529
# 4  3F9E0C51F49F78A3  electric_bike 2022-01-01 20:05:19.592
#
#                  ended_at      start_station_name start_station_id  \
# 0 2022-01-01 01:57:50.346   Canal St & Rutgers St          5303.08
# 1 2022-01-01 03:49:33.047  Lewis Ave & Madison St          4425.02
# 2 2022-01-01 08:47:54.213  Carlton Ave & Park Ave          4732.04
# 3 2022-01-01 10:47:05.197     W 100 St & Broadway          7580.01
# 4 2022-01-01 20:12:00.661         W 18 St & 6 Ave          6064.08
#
#           end_station_name end_station_id member_casual       date  AWND  \
# 0   Norfolk St & Broome St        5374.01        casual 2022-01-01    28
# 1  Columbia St & Degraw St        4422.04        member 2022-01-01    28
# 2  Emerson Pl & Myrtle Ave        4683.02        casual 2022-01-01    28
# 3       W 67 St & Broadway        7116.04        casual 2022-01-01    28
# 4          W 42 St & 6 Ave        6517.08        member 2022-01-01    28
#
#    PRCP  TAVG  start_lat  start_lng    end_lat    end_lng  trip_duration
# 0   193   116  40.714275 -73.989900  40.717227 -73.988021       8.216200
# 1   193   116  40.686312 -73.935775  40.685930 -74.002424      28.388217
# 2   193   116  40.695807 -73.973556  40.693631 -73.962236       9.600950
# 3   193   116  40.797372 -73.970412  40.774925 -73.982666      13.111133
# 4   193   116  40.739713 -73.994564  40.754920 -73.984550       6.684483

# %%
# creating aggregated df with # of trips between stations
# keeping variables needed for graphs. Taking most common values of coordinates in case they differ anywhere
df_trips = (
    df.groupby(['start_station_name', 'end_station_name'])
      .agg({
          'ride_id': 'count',
          'start_lat': lambda x: x.mode().iloc[0] if not x.mode().empty else None,
          'start_lng': lambda x: x.mode().iloc[0] if not x.mode().empty else None,
          'end_lat': lambda x: x.mode().iloc[0] if not x.mode().empty else None,
          'end_lng': lambda x: x.mode().iloc[0] if not x.mode().empty else None})
      .reset_index()
      .rename(columns={'ride_id': 'num_trips'})
      .sort_values(by=['num_trips'],
                   ascending=False)
      .copy()
)

# %%
df_trips.head(20)
# Out:
#                         start_station_name                   end_station_name  \
# 292588              Central Park S & 6 Ave             Central Park S & 6 Ave
# 147007          7 Ave & Central Park South         7 Ave & Central Park South
# 777093            Roosevelt Island Tramway           Roosevelt Island Tramway
# 544121   Grand Army Plaza & Central Park S  Grand Army Plaza & Central Park S
# 795202                    Soissons Landing                   Soissons Landing
# 891295                     W 21 St & 6 Ave                    9 Ave & W 22 St
# 118879                     5 Ave & E 72 St                    5 Ave & E 72 St
# 6514                       1 Ave & E 62 St                    1 Ave & E 68 St
# 1006565              Yankee Ferry Terminal              Yankee Ferry Terminal
# 253043                  Broadway & W 58 St                 Broadway & W 58 St
# 21335                     12 Ave & W 40 St                   12 Ave & W 40 St
# 249036                  Broadway & W 41 St                 Broadway & W 41 St
# 296910         Central Park West & W 72 St        Central Park West & W 72 St
# 717592              Norfolk St & Broome St                Henry St & Grand St
# 984040               West St & Chambers St              West St & Chambers St
# 979743     West Drive & Prospect Park West    West Drive & Prospect Park West
# 983774               West St & Chambers St        Pier 40 - Hudson River Park
# 120638                     5 Ave & E 87 St                    5 Ave & E 87 St
# 1006549              Yankee Ferry Terminal                   Soissons Landing
# 719241       North Moore St & Greenwich St               Vesey St & Church St
#
#          num_trips  start_lat  start_lng    end_lat    end_lng
# 292588       12041  40.765909 -73.976342  40.765909 -73.976342
# 147007        8541  40.766741 -73.979069  40.766741 -73.979069
# 777093        8213  40.757284 -73.953600  40.757284 -73.953600
# 544121        7287  40.764397 -73.973715  40.764397 -73.973715
# 795202        7275  40.692317 -74.014866  40.692317 -74.014866
# 891295        6345  40.741740 -73.994156  40.745497 -74.001971
# 118879        6037  40.772828 -73.966853  40.772828 -73.966853
# 6514          5826  40.761227 -73.960940  40.765005 -73.958185
# 1006565       5759  40.687066 -74.016756  40.687066 -74.016756
# 253043        5509  40.766953 -73.981693  40.766953 -73.981693
# 21335         5409  40.760875 -74.002777  40.760875 -74.002777
# 249036        5316  40.755136 -73.986580  40.755136 -73.986580
# 296910        5262  40.775794 -73.976206  40.775794 -73.976206
# 717592        4883  40.717227 -73.988021  40.714211 -73.981095
# 984040        4768  40.717548 -74.013221  40.717548 -74.013221
# 979743        4643  40.661063 -73.979453  40.661063 -73.979453
# 983774        4584  40.717548 -74.013221  40.727714 -74.011296
# 120638        4571  40.782323 -73.959875  40.782323 -73.959875
# 1006549       4556  40.687066 -74.016756  40.692317 -74.014866
# 719241        4523  40.720195 -74.010301  40.712220 -74.010472

# %% [markdown]
# 14/20 of the top routes start and end at same station

# %%
df_trips.shape
# Out:
# (1006566, 7)

# %%
# check number of trips
print(df_trips['num_trips'].sum())
print(len(df))
# Out:
# 29767925
# 29767925

# %% [markdown]
# Aggrgation worked properly

# %%
# Checking what percentage of trips start and ended at same station
# Total number of trips
total_trips = df_trips['num_trips'].sum()

# Trips where start and end station are the same
round_trips = df_trips[df_trips['start_station_name'] == df_trips['end_station_name']]['num_trips'].sum()

# Percentage
round_trip_percent = (round_trips / total_trips) * 100

print(f"Percentage of round trips: {round_trip_percent:.2f}%")
# Out:
# Percentage of round trips: 3.28%

# %%
# Limit df to top 1000 routes to vizualise
top_1000 = df_trips.sort_values('num_trips', ascending=False).head(1000).copy()

# %%
m = KeplerGl(height = 700, data={"data_1": top_1000})
m
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(data={'data_1':                         start_station_name                   end_station_name  \
# 2925…

# %%
# save settings
config = m.config

# %%
import json
with open("config_routes.json", "w") as outfile:
    json.dump(config, outfile)

# %%
m.save_to_html(file_name = '../visualisations/routes.html', 
               read_only = False, 
               config = config)
# Out:
# Map saved to ../visualisations/routes.html!
