# %%
import pandas as pd
import numpy as np
from keplergl import KeplerGl
from pyproj import CRS
from matplotlib import pyplot as plt
import os
# Out:
# c:\Users\seank\OneDrive\Dokumente\Career Foundry Data Analytics Course\Python_visualisation\CitiBike_NY\venv\Lib\site-packages\keplergl\keplergl.py:13: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_string

# %%
df = pd.read_parquet(r'C:\Data\Citibike_NY_2022\merged\df_weather_duration.parquet')

# %%
df.head()
# Out:
#                  ride_id  rideable_type              started_at  \
# 337365  FB33E3D8F21E2941  electric_bike 2022-01-01 01:49:37.374
# 934147  755337295F178067  electric_bike 2022-01-01 03:21:09.754
# 227118  C62CA87E3A475ADD   classic_bike 2022-01-01 08:38:18.156
# 913138  CD7A2098AFCD5514   classic_bike 2022-01-01 10:33:58.529
# 127328  3F9E0C51F49F78A3  electric_bike 2022-01-01 20:05:19.592
#
#                       ended_at      start_station_name start_station_id  \
# 337365 2022-01-01 01:57:50.346   Canal St & Rutgers St          5303.08
# 934147 2022-01-01 03:49:33.047  Lewis Ave & Madison St          4425.02
# 227118 2022-01-01 08:47:54.213  Carlton Ave & Park Ave          4732.04
# 913138 2022-01-01 10:47:05.197     W 100 St & Broadway          7580.01
# 127328 2022-01-01 20:12:00.661         W 18 St & 6 Ave          6064.08
#
#                end_station_name end_station_id  start_lat  start_lng  \
# 337365   Norfolk St & Broome St        5374.01  40.714275 -73.989900
# 934147  Columbia St & Degraw St        4422.04  40.686312 -73.935775
# 227118  Emerson Pl & Myrtle Ave        4683.02  40.695807 -73.973556
# 913138       W 67 St & Broadway        7116.04  40.797372 -73.970412
# 127328          W 42 St & 6 Ave        6517.08  40.739713 -73.994564
#
#           end_lat    end_lng member_casual       date  AWND  PRCP  TAVG  \
# 337365  40.717227 -73.988021        casual 2022-01-01    28   193   116
# 934147  40.685930 -74.002424        member 2022-01-01    28   193   116
# 227118  40.693631 -73.962236        casual 2022-01-01    28   193   116
# 913138  40.774925 -73.982666        casual 2022-01-01    28   193   116
# 127328  40.754920 -73.984550        member 2022-01-01    28   193   116
#
#        _merge  trip_duration
# 337365   both       8.216200
# 934147   both      28.388217
# 227118   both       9.600950
# 913138   both      13.111133
# 127328   both       6.684483

# %%
df.shape
# Out:
# (29596596, 19)

# %%
# creating aggregated df with # of trips between stations
df_trips = (
    df.groupby(['start_station_name', 'end_station_name'])
      .size()
      .reset_index(name='value')
      .sort_values(by=['value'],
                   ascending=False)
      .copy()
)

# %%
df_trips.head(20)
# Out:
#                         start_station_name                   end_station_name  \
# 292912              Central Park S & 6 Ave             Central Park S & 6 Ave
# 146804          7 Ave & Central Park South         7 Ave & Central Park South
# 777076            Roosevelt Island Tramway           Roosevelt Island Tramway
# 544522   Grand Army Plaza & Central Park S  Grand Army Plaza & Central Park S
# 795170                    Soissons Landing                   Soissons Landing
# 890893                     W 21 St & 6 Ave                    9 Ave & W 22 St
# 118619                     5 Ave & E 72 St                    5 Ave & E 72 St
# 6506                       1 Ave & E 62 St                    1 Ave & E 68 St
# 1006462              Yankee Ferry Terminal              Yankee Ferry Terminal
# 21285                     12 Ave & W 40 St                   12 Ave & W 40 St
# 248778                  Broadway & W 41 St                 Broadway & W 41 St
# 253324                  Broadway & W 58 St                 Broadway & W 58 St
# 297217         Central Park West & W 72 St        Central Park West & W 72 St
# 717855              Norfolk St & Broome St                Henry St & Grand St
# 984023               West St & Chambers St              West St & Chambers St
# 983760               West St & Chambers St        Pier 40 - Hudson River Park
# 979739     West Drive & Prospect Park West    West Drive & Prospect Park West
# 719500       North Moore St & Greenwich St               Vesey St & Church St
# 120366                     5 Ave & E 87 St                    5 Ave & E 87 St
# 891666                     W 21 St & 6 Ave                   W 22 St & 10 Ave
#
#          value
# 292912   11579
# 146804    8097
# 777076    7962
# 544522    6869
# 795170    6679
# 890893    6338
# 118619    5891
# 6506      5823
# 1006462   5249
# 21285     5243
# 248778    5223
# 253324    5178
# 297217    5138
# 717855    4873
# 984023    4662
# 983760    4566
# 979739    4561
# 719500    4523
# 120366    4433
# 891666    4407

# %%
# check number of trips
print(df_trips['value'].sum())
# Out:
# 29596596

# %% [markdown]
# merging coordinates onto aggregated df

# %%
# first capturing coordinates
start_locs = df[['start_station_name', 'start_lat', 'start_lng']].drop_duplicates(subset='start_station_name')

# %%
end_locs = df[['end_station_name', 'end_lat', 'end_lng']].drop_duplicates(subset='end_station_name')

# %%
df_trips = df_trips.merge(start_locs, on='start_station_name', how='left')
df_trips.head()
# Out:
#                   start_station_name                   end_station_name  \
# 0             Central Park S & 6 Ave             Central Park S & 6 Ave
# 1         7 Ave & Central Park South         7 Ave & Central Park South
# 2           Roosevelt Island Tramway           Roosevelt Island Tramway
# 3  Grand Army Plaza & Central Park S  Grand Army Plaza & Central Park S
# 4                   Soissons Landing                   Soissons Landing
#
#    value  start_lat  start_lng
# 0  11579  40.765909 -73.976342
# 1   8097  40.766741 -73.979069
# 2   7962  40.757284 -73.953600
# 3   6869  40.764397 -73.973715
# 4   6679  40.692317 -74.014866

# %%
df_trips = df_trips.merge(end_locs, how='left', on='end_station_name')

# %%
df_trips.head()
# Out:
#                   start_station_name                   end_station_name  \
# 0             Central Park S & 6 Ave             Central Park S & 6 Ave
# 1         7 Ave & Central Park South         7 Ave & Central Park South
# 2           Roosevelt Island Tramway           Roosevelt Island Tramway
# 3  Grand Army Plaza & Central Park S  Grand Army Plaza & Central Park S
# 4                   Soissons Landing                   Soissons Landing
#
#    value  start_lat  start_lng    end_lat    end_lng
# 0  11579  40.765909 -73.976342  40.765909 -73.976342
# 1   8097  40.766741 -73.979069  40.766741 -73.979069
# 2   7962  40.757284 -73.953600  40.757284 -73.953600
# 3   6869  40.764397 -73.973715  40.764397 -73.973715
# 4   6679  40.692317 -74.014866  40.692317 -74.014866

# %% [markdown]
# ## Plotting map with KeplerGL

# %%
# Create KeplerGl instance

m = KeplerGl(height = 700, data={"data_1": df_trips})
m
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(data={'data_1':                         start_station_name                   end_station_name  \
# 0   …

# %% [markdown]
# Using orange to blue for colourblind, but also because it's the knicks colours.
# Filtered out trips with less than 900 since there were far too many lines on map.
# Red/dark orange dot represents higher amount of trips starting from there.
# We can see that up along the West coast of lower manhattan there are a number of popular routes, as well as a large number number of short routes between different locations between 30th-50th street. There's also a number of popular routes in Brooklyn that end around the Williamsburg bridge.

# %%
# save settings
config = m.config

# %%
import json
with open("config.json", "w") as outfile:
    json.dump(config, outfile)

# %%
m.save_to_html(file_name = '../visualisations/NY_trips.html', read_only = False, config = config)
# Out:
# Map saved to ../visualisations/NY_trips.html!
